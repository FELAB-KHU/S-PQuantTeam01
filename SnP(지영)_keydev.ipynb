# %% [markdown]
# ## 라이브러리 설치

# %%
pip install pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ------------------

# %% [markdown]
# ## Keydev

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd

user = 'felab'
password = 'rlawkdgh'
host = '192.168.0.2'  # 포트 번호를 여기에 포함하지 않습니다.
port = 3306  # 포트 번호를 별도의 변수로 설정합니다.
database = 'db'
table_name = 'keydev' #읽고 싶은 데이터셋.

# SQLAlchemy 엔진 생성 시 호스트와 포트를 정확하게 지정합니다.
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

# pymysql 연결 시에도 마찬가지로 호스트와 포트를 정확하게 지정합니다.
connection = pymysql.connect(host=host, port=port, user=user, password=password, database=database, connect_timeout = 10)

# 모든 컬럼 불러오기
query = f"SELECT * FROM {table_name}" # 원하는 쿼리. SQL 지식 필요함

# 원하는 컬럼 불러오기
# query = f"SELECT keyDevEventTypeName FROM {table_name}" # 원하는 쿼리. SQL 지식 필요함
keydev = pd.read_sql(query, engine)
keydev
# Out:
#             companyId                           companyName      keyDevId  \
# 0        1.850100e+04                  21 Invest Sgr S.p.A.  1.786392e+09
# 1        1.850100e+04                  21 Invest Sgr S.p.A.  1.775873e+09
# 2        1.851100e+04                          3i Group plc  1.856147e+09
# 3        1.851100e+04                          3i Group plc  1.846370e+09
# 4        1.851100e+04                          3i Group plc  1.843429e+09
# ...               ...                                   ...           ...
# 3244073  2.147481e+09  Centennial Emergency Physicians, LLC  1.846943e+09
# 3244074  2.147481e+09  Centennial Emergency Physicians, LLC  1.846939e+09
# 3244075  2.147481e+09  Centennial Emergency Physicians, LLC  1.838307e+09
# 3244076  2.147481e+09  Centennial Emergency Physicians, LLC  1.837743e+09
# 3244077  2.147481e+09  Centennial Emergency Physicians, LLC  1.838307e+09
#
#                                                   headline  \
# ...

# %% [markdown]
# ## Company (행 7천개밖에 없음)

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd

user = 'felab'
password = 'rlawkdgh'
host = '192.168.0.2'  # 포트 번호를 여기에 포함하지 않습니다.
port = 3306  # 포트 번호를 별도의 변수로 설정합니다.
database = 'db'
table_name = 'company' #읽고 싶은 데이터셋.

# SQLAlchemy 엔진 생성 시 호스트와 포트를 정확하게 지정합니다.
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

# pymysql 연결 시에도 마찬가지로 호스트와 포트를 정확하게 지정합니다.
connection = pymysql.connect(host=host, port=port, user=user, password=password, database=database)

query = f"SELECT * FROM {table_name}" # 원하는 쿼리. SQL 지식 필요함
company = pd.read_sql(query, engine)
company
# Out:
#       companyId                             companyName  \
# 0       18493.0                     DC Venture Partners
# 1       18495.0                 13i Capital Corporation
# 2       18499.0          21 International Holdings Inc.
# 3       18501.0                    21 Invest Sgr S.p.A.
# 4       18505.0              Palo Alto Venture Partners
# ...         ...                                     ...
# 7140    29969.0     Insight Communications Company Inc.
# 7141    29970.0                     Insight Development
# 7142    29971.0  InSight Health Services Holdings Corp.
# 7143    29972.0                      InsightExpress LLC
# 7144    29973.0          Insignia Financial Group, Inc.
#
#                      streetAddress        country  officePhoneValue  \
# 0        1103 Riverbend Club Drive  United States      770-612-9190
# 1                2021 Midwest Road  United States      630-620-2255
# 2                             None  United States              None
# ...

# %% [markdown]
# ## Market (미업로드)

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd

user = 'felab'
password = 'rlawkdgh'
host = '192.168.0.2'  # 포트 번호를 여기에 포함하지 않습니다.
port = 3306  # 포트 번호를 별도의 변수로 설정합니다.
database = 'db'
table_name = 'market' #읽고 싶은 데이터셋.

# SQLAlchemy 엔진 생성 시 호스트와 포트를 정확하게 지정합니다.
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

# pymysql 연결 시에도 마찬가지로 호스트와 포트를 정확하게 지정합니다.
connection = pymysql.connect(host=host, port=port, user=user, password=password, database=database)

query = f"SELECT * FROM {table_name}" # 원하는 쿼리. SQL 지식 필요함
market = pd.read_sql(query, engine)
market
# Out:
# Empty DataFrame
# Columns: [companyId, companyName, tickerSymbol, exchangeSymbol, ISOCode, pricingDate, exDate, payDate, recordDate, announcedDate, priceClose, volume, adjustmentFactor, VWAP, divAdjFactor, marketCap, TEV, sharesOutstanding, divFreqTypeName, supplementalTypeName, dividendTypeName, divAmount, netAmount, grossAmount]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# ## Estimates

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd

user = 'felab'
password = 'rlawkdgh'
host = '192.168.0.2'  # 포트 번호를 여기에 포함하지 않습니다.
port = 3306  # 포트 번호를 별도의 변수로 설정합니다.
database = 'db'
table_name = 'estimates' #읽고 싶은 데이터셋.

# SQLAlchemy 엔진 생성 시 호스트와 포트를 정확하게 지정합니다.
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

# pymysql 연결 시에도 마찬가지로 호스트와 포트를 정확하게 지정합니다.
connection = pymysql.connect(host=host, port=port, user=user, password=password, database=database)

query = f"SELECT * FROM {table_name}" # 원하는 쿼리. SQL 지식 필요함
estimates = pd.read_sql(query, engine)
estimates
# Out:
#             companyId         companyName  fiscalQuarter  fiscalYear  \
# 0        1.851100e+04        3i Group plc            0.0         0.0
# 1        1.851100e+04        3i Group plc            4.0      2021.0
# 2        1.851100e+04        3i Group plc            4.0      2025.0
# 3        1.851100e+04        3i Group plc            4.0      2024.0
# 4        1.851100e+04        3i Group plc            4.0      2022.0
# ...               ...                 ...            ...         ...
# 2121823  1.851035e+09  Liberty Live Group            0.0         0.0
# 2121824  1.851035e+09  Liberty Live Group            0.0         0.0
# 2121825  1.851035e+09  Liberty Live Group            0.0         0.0
# 2121826  1.851035e+09  Liberty Live Group            0.0         0.0
# 2121827  1.851035e+09  Liberty Live Group            0.0         0.0
#
#         periodEndDate         advanceDate       effectiveDate     toDate  \
# ...

# %% [markdown]
# ## Exchangerate

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd

user = 'felab'
password = 'rlawkdgh'
host = '192.168.0.2'  # 포트 번호를 여기에 포함하지 않습니다.
port = 3306  # 포트 번호를 별도의 변수로 설정합니다.
database = 'db'
table_name = 'exchangerate' #읽고 싶은 데이터셋.

# SQLAlchemy 엔진 생성 시 호스트와 포트를 정확하게 지정합니다.
engine = create_engine(f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}")

# pymysql 연결 시에도 마찬가지로 호스트와 포트를 정확하게 지정합니다.
connection = pymysql.connect(host=host, port=port, user=user, password=password, database=database)

query = f"SELECT * FROM {table_name}" # 원하는 쿼리. SQL 지식 필요함
exchangerate = pd.read_sql(query, engine)
exchangerate
# Out:
#        ISOCode  priceDate    priceClose
# 0          PTE 2021-03-20    178.318715
# 1          ROL 2021-03-20  25789.000000
# 2          SDD 2021-03-20    203.090000
# 3          SIT 2021-03-20    213.147798
# 4          SKK 2021-03-20     26.795571
# ...        ...        ...           ...
# 494831     BZD 2018-08-17      2.015300
# 494832     BZD 2018-08-18      2.015300
# 494833     BZD 2018-08-19      2.015300
# 494834     BZD 2018-08-20      2.015300
# 494835     BZD 2018-08-21      2.015300
#
# [494836 rows x 3 columns]

# %% [markdown]
# ## Financials  (미업로드)

# %% [markdown]
# --------------------

# %%
keydev
# Out:
#             companyId                           companyName      keyDevId  \
# 0        1.850100e+04                  21 Invest Sgr S.p.A.  1.786392e+09
# 1        1.850100e+04                  21 Invest Sgr S.p.A.  1.775873e+09
# 2        1.851100e+04                          3i Group plc  1.856147e+09
# 3        1.851100e+04                          3i Group plc  1.846370e+09
# 4        1.851100e+04                          3i Group plc  1.843429e+09
# ...               ...                                   ...           ...
# 3244073  2.147481e+09  Centennial Emergency Physicians, LLC  1.846943e+09
# 3244074  2.147481e+09  Centennial Emergency Physicians, LLC  1.846939e+09
# 3244075  2.147481e+09  Centennial Emergency Physicians, LLC  1.838307e+09
# 3244076  2.147481e+09  Centennial Emergency Physicians, LLC  1.837743e+09
# 3244077  2.147481e+09  Centennial Emergency Physicians, LLC  1.838307e+09
#
#                                                   headline  \
# ...

# %%
keydev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3244078 entries, 0 to 3244077
# Data columns (total 8 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   companyId             float64
#  1   companyName           object
#  2   keyDevId              float64
#  3   headline              object
#  4   situation             object
#  5   announcedDate         datetime64[ns]
#  6   mostImportantDateUTC  datetime64[ns]
#  7   keyDevEventTypeName   object
# dtypes: datetime64[ns](2), float64(2), object(4)
# memory usage: 198.0+ MB

# %%
# 각 컬럼별로 null값의 갯수 확인
keydev.isnull().sum()
# Out:
# companyId               0
# companyName             0
# keyDevId                0
# headline                0
# situation               4
# announcedDate           0
# mostImportantDateUTC    0
# keyDevEventTypeName     0
# dtype: int64

# %%
# 원본 데이터프레임에서 null값을 포함한 행 삭제
keydev.dropna(inplace=True)

# %%
keydev
# Out:
#             companyId                           companyName      keyDevId  \
# 0        1.850100e+04                  21 Invest Sgr S.p.A.  1.786392e+09
# 1        1.850100e+04                  21 Invest Sgr S.p.A.  1.775873e+09
# 2        1.851100e+04                          3i Group plc  1.856147e+09
# 3        1.851100e+04                          3i Group plc  1.846370e+09
# 4        1.851100e+04                          3i Group plc  1.843429e+09
# ...               ...                                   ...           ...
# 3244073  2.147481e+09  Centennial Emergency Physicians, LLC  1.846943e+09
# 3244074  2.147481e+09  Centennial Emergency Physicians, LLC  1.846939e+09
# 3244075  2.147481e+09  Centennial Emergency Physicians, LLC  1.838307e+09
# 3244076  2.147481e+09  Centennial Emergency Physicians, LLC  1.837743e+09
# 3244077  2.147481e+09  Centennial Emergency Physicians, LLC  1.838307e+09
#
#                                                   headline  \
# ...

# %%
# 'companyName' 컬럼 안에 있는 고유한 데이터 확인
unique_values = keydev['companyName'].unique()
num_unique = len(unique_values)
print("컬럼 'Category' 안에 몇 종류의 데이터가 있는지:", num_unique)
print("고유한 데이터:", unique_values)
# Out:
# 컬럼 'Category' 안에 몇 종류의 데이터가 있는지: 454483
# 고유한 데이터: ['21 Invest Sgr S.p.A.' '3i Group plc' 'Pappas Capital, LLC' ...
#  'Aries G.K.'
#  'Industrial manufacturing property located in Alleyton, Texas'
#  'Centennial Emergency Physicians, LLC']

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
keydev['companyName'] = label_encoder.fit_transform(keydev['companyName'])

# %%
keydev
# Out:
#             companyId                           companyName      keyDevId  \
# 0        1.850100e+04                  21 Invest Sgr S.p.A.  1.786392e+09
# 1        1.850100e+04                  21 Invest Sgr S.p.A.  1.775873e+09
# 2        1.851100e+04                          3i Group plc  1.856147e+09
# 3        1.851100e+04                          3i Group plc  1.846370e+09
# 4        1.851100e+04                          3i Group plc  1.843429e+09
# ...               ...                                   ...           ...
# 3244069  2.147481e+09  Centennial Emergency Physicians, LLC  1.846943e+09
# 3244070  2.147481e+09  Centennial Emergency Physicians, LLC  1.846939e+09
# 3244071  2.147481e+09  Centennial Emergency Physicians, LLC  1.838307e+09
# 3244072  2.147481e+09  Centennial Emergency Physicians, LLC  1.837743e+09
# 3244073  2.147481e+09  Centennial Emergency Physicians, LLC  1.838307e+09
#
#                                                   headline  \
# ...

# %% [markdown]
# keydev 전처리 관련 질문
# 1. 텍스트 분석(감성분석)을 어떻게 해야할 지 -> situation 컬럼 하나로 하자
#     의문 : 감성분석할 때, (+)(-)(0) 를 구별해야하는데,
#     감성 분석 하려면, 컬럼(situation) 사용보다 뉴스 크롤링해야하는데, 얘가 메인업무량이 될까바 ,,, 흠
# 2. 회사 종류 454483개 -> 얘를 어떻게 해야할 지 : 상장/비상장인지 여부를 여기서 확인하거나 다른 df 연동시켜야하는데 연동방법 몰라,,
# 3. companyID -> company table에서 ticker와 연동하면되고, 구글링 ㄱ
#
# 의견
# - 최대한 간단하게 작업을 끝내놓고(산업군 분석, 상승할/하락할 산업군 비중 최적화 한다던지)
# - 거시 경제 지표 최대한 활용해서 산업군 분석 예정(금리, 환율, 인플레이션, 경제 성장률, 고용률, 실업률 등등 이 중에서 있는 데이터 활용)
# - 산업군 분석 -> 상승할 것들 종목 확인 해서 가치지표 (PER, ROE) 활용해서 스크리닝한다던지 등
# - 이렇게 할거면, 데이터 다시 봐서 산업군 분석에 사용할 수 있는 데이터 먼저 고르기 -> 가치지표 어떻게 활용할지 고르기
# - 산업군 분석 어떻게 진행하는 지 조사 후 우리 데이터랑 쓸만한 컬럼 비교해서 의견 나누기
# - 데이터 전처리 팁 ! 우선, 투자 안할 회사들(티커 company 테이블, 재균오빠 파일 참고) , 비상장종목, ticker-companyID 안맞는거 제거하면 용량 많이 제거됨
#
# 월요일 13시 30분 회의
# - 지금까지 의견 나온거 종합해서 각자의 아이디어 활용해서 데이터 전처리 방안, 분석 방안, 구현 방안 논의할거 정리해오기
# - 월요일에 교수님 피드백 받을 내용 준비하기

# %%
print('dsfsfsdf')
# Out:
# dsfsfsdf
