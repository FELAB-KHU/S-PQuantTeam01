# %%
# %matplotlib inline

import matplotlib. pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
new_market = pd.read_csv('./new_market.csv')

# %% [markdown]
# # **Out-of-Sample**

# %% [markdown]
# ## **ChatGPT**

# %% [markdown]
# ### GPT-weighted

# %%
# GPT-weighted_15 주간수익률

# 자산 비중
stocks_15 = {
    "AAPL": 0.084,
    "AMZN": 0.074,
    "NVDA": 0.064,
    "JPM": 0.054,
    "PG": 0.054,
    "PFE": 0.064,
    "JNJ": 0.064,
    "KO": 0.054,
    "XOM": 0.064,
    "NEE": 0.074,
    "GOOGL": 0.084,
    "MSFT": 0.084,
    "TSLA": 0.074,
    "NKE": 0.054,
    "BAC": 0.054
}

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(stocks_15.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(stocks_15))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_gpt_15 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_gpt_15 = pd.DataFrame(weekly_returns_gpt_15, columns=['GPT-weighted_15'])

# %%
# GPT-weighted_30 주간수익률

# 자산 비중
stocks_30 = {
    "MSFT": 0.067,
    "AMZN": 0.067,
    "NVDA": 0.067,
    "AAPL": 0.067,
    "GOOGL": 0.067,
    "ADBE": 0.067,
    "JNJ": 0.05,
    "PFE": 0.05,
    "MRK": 0.05,
    "ABT": 0.05,
    "PG": 0.05,
    "KO": 0.05,
    "JPM": 0.05,
    "GS": 0.05,
    "CAT": 0.025,
    "CVX": 0.025,
    "XOM": 0.025,
    "BA": 0.025,
    "TSLA": 0.025,
    "NEE": 0.025,
    "NKE": 0.005,
    "VZ": 0.005,
    "CRM": 0.005,
    "UNH": 0.005,
    "WMT": 0.005,
    "QCOM": 0.005,
    "BAC": 0.005,
    "V": 0.005,
    "MCD": 0.005,
    "INTC": 0.005
}

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(stocks_30.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(stocks_30))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_gpt_30 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_gpt_30 = pd.DataFrame(weekly_returns_gpt_30, columns=['GPT-weighted_30'])

# %%
# GPT-weighted_45 주간수익률

# 자산 비중
stocks_45 = {
    "AAPL": 0.05, "GOOGL": 0.04, "MSFT": 0.04, "NVDA": 0.03, "AMD": 0.03, "ORCL": 0.02, "CRM": 0.02, "INTC": 0.01, "CSCO": 0.01,
    "JPM": 0.04, "GS": 0.03, "BAC": 0.03, "MS": 0.02, "AXP": 0.02, "C": 0.01,
    "JNJ": 0.03, "UNH": 0.03, "PFE": 0.02, "ABBV": 0.02, "MRK": 0.02, "AMGN": 0.02, "GILD": 0.01,
    "PG": 0.03, "KO": 0.03, "NKE": 0.02, "PEP": 0.02, "COST": 0.02, "WMT": 0.02, "TGT": 0.01,
    "XOM": 0.025, "CVX": 0.025, "NEE": 0.02, "DUK": 0.01, "SO": 0.01, "SLB": 0.01,
    "MMM": 0.02, "CAT": 0.02, "HON": 0.02, "GE": 0.02, "ADP": 0.02,
    "AMZN": 0.02, "META": 0.02, "HD": 0.02, "VZ": 0.01, "MRK": 0.01
}

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(stocks_45.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(stocks_45))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_gpt_45 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_gpt_45 = pd.DataFrame(weekly_returns_gpt_45, columns=['GPT-weighted_45'])

# %% [markdown]
# ### GPT-equal

# %%
# GPT-equal_15 주간수익률

# 자산 비중
stocks_15_equal = {
    "AAPL": 0.06666666666666667,
    "AMZN": 0.06666666666666667,
    "NVDA": 0.06666666666666667,
    "JPM": 0.06666666666666667,
    "PG": 0.06666666666666667,
    "PFE": 0.06666666666666667,
    "JNJ": 0.06666666666666667,
    "KO": 0.06666666666666667,
    "XOM": 0.06666666666666667,
    "NEE": 0.06666666666666667,
    "GOOGL": 0.06666666666666667,
    "MSFT": 0.06666666666666667,
    "TSLA": 0.06666666666666667,
    "NKE": 0.06666666666666667,
    "BAC": 0.06666666666666667
}

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(stocks_15_equal.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(stocks_15_equal))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_gpt_equal_15 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_gpt_equal_15 = pd.DataFrame(weekly_returns_gpt_equal_15, columns=['GPT-equal_15'])

# %%
# GPT-equal_30 주간수익률

# 자산 비중
stocks_30_equal = {
    "MSFT": 0.03333333333333333,
    "AMZN": 0.03333333333333333,
    "NVDA": 0.03333333333333333,
    "AAPL": 0.03333333333333333,
    "GOOGL": 0.03333333333333333,
    "ADBE": 0.03333333333333333,
    "JNJ": 0.03333333333333333,
    "PFE": 0.03333333333333333,
    "MRK": 0.03333333333333333,
    "ABT": 0.03333333333333333,
    "PG": 0.03333333333333333,
    "KO": 0.03333333333333333,
    "JPM": 0.03333333333333333,
    "GS": 0.03333333333333333,
    "CAT": 0.03333333333333333,
    "CVX": 0.03333333333333333,
    "XOM": 0.03333333333333333,
    "BA": 0.03333333333333333,
    "TSLA": 0.03333333333333333,
    "NEE": 0.03333333333333333,
    "NKE": 0.03333333333333333,
    "VZ": 0.03333333333333333,
    "CRM": 0.03333333333333333,
    "UNH": 0.03333333333333333,
    "WMT": 0.03333333333333333,
    "QCOM": 0.03333333333333333,
    "BAC": 0.03333333333333333,
    "V": 0.03333333333333333,
    "MCD": 0.03333333333333333,
    "INTC": 0.03333333333333333
}

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(stocks_30_equal.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(stocks_30_equal))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_gpt_equal_30 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_gpt_equal_30 = pd.DataFrame(weekly_returns_gpt_equal_30, columns=['GPT-equal_30'])

# %%
# GPT-equal_45 주간수익률

# 자산 비중
stocks_45_equal = {
    "AAPL": 0.022222,
    "GOOGL": 0.022222,
    "MSFT": 0.022222,
    "NVDA": 0.022222,
    "AMD": 0.022222,
    "ORCL": 0.022222,
    "CRM": 0.022222,
    "INTC": 0.022222,
    "CSCO": 0.022222,
    "JPM": 0.022222,
    "GS": 0.022222,
    "BAC": 0.022222,
    "MS": 0.022222,
    "AXP": 0.022222,
    "C": 0.022222,
    "JNJ": 0.022222,
    "UNH": 0.022222,
    "PFE": 0.022222,
    "ABBV": 0.022222,
    "MRK": 0.022222,
    "AMGN": 0.022222,
    "GILD": 0.022222,
    "PG": 0.022222,
    "KO": 0.022222,
    "NKE": 0.022222,
    "PEP": 0.022222,
    "COST": 0.022222,
    "WMT": 0.022222,
    "TGT": 0.022222,
    "XOM": 0.022222,
    "CVX": 0.022222,
    "NEE": 0.022222,
    "DUK": 0.022222,
    "SO": 0.022222,
    "SLB": 0.022222,
    "MMM": 0.022222,
    "CAT": 0.022222,
    "HON": 0.022222,
    "GE": 0.022222,
    "ADP": 0.022222,
    "AMZN": 0.022222,
    "META": 0.022222,
    "HD": 0.022222,
    "VZ": 0.022222,
    "MRK": 0.022222,
}

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(stocks_45_equal.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(stocks_45_equal))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_gpt_equal_45 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_gpt_equal_45 = pd.DataFrame(weekly_returns_gpt_equal_45, columns=['GPT-equal_45'])

# %% [markdown]
# ## **MVO**

# %% [markdown]
# ### GMV

# %%
MVO_GMV_weighted_15 = {'AAPL': 0.03333374405100818,
 'AMZN': 0.033334588116497435,
 'NVDA': 0.03333348978722604,
 'JPM': 0.03333398514503214,
 'PG': 0.1333327361134369,
 'PFE': 0.13333243975930342,
 'JNJ': 0.1333328801282149,
 'KO': 0.13333263630232933,
 'XOM': 0.06275993684703628,
 'NEE': 0.10390437355944876,
 'GOOGL': 0.033334014760777,
 'MSFT': 0.03333378694216374,
 'TSLA': 0.033333526201165434,
 'NKE': 0.03333412746870001,
 'BAC': 0.03333373481766047}

MVO_GMV_weighted_30 = {'MSFT': 0.016666721079821905,
 'AMZN': 0.016667167540343083,
 'NVDA': 0.016666684870667,
 'AAPL': 0.016666718865478672,
 'GOOGL': 0.016666761861858326,
 'ADBE': 0.016666712765385196,
 'JNJ': 0.06666662398032082,
 'PFE': 0.06666660776982793,
 'MRK': 0.06666662164123628,
 'ABT': 0.04919809474758443,
 'PG': 0.0666666152279637,
 'KO': 0.06666660761263403,
 'JPM': 0.01666673750868713,
 'GS': 0.016666730499348244,
 'CAT': 0.016666892718601656,
 'CVX': 0.01666675225225722,
 'XOM': 0.034133822269706314,
 'BA': 0.016666688590042056,
 'TSLA': 0.016666694041226473,
 'NEE': 0.06666643755151765,
 'NKE': 0.016666773473371085,
 'VZ': 0.06666663719805763,
 'CRM': 0.016666720018305783,
 'UNH': 0.016667066546555444,
 'WMT': 0.0666666332890372,
 'QCOM': 0.016666711438264183,
 'BAC': 0.016666710161146746,
 'V': 0.016666754085972495,
 'MCD': 0.06666658915468787,
 'INTC': 0.016666711240093342}

MVO_GMV_weighted_45 = {'AAPL': 0.011111213758484832,
 'GOOGL': 0.011111343139537204,
 'MSFT': 0.011111225007998026,
 'NVDA': 0.011111151895228117,
 'AMD': 0.011111160772805313,
 'ORCL': 0.011111789666104675,
 'CRM': 0.011111258185929706,
 'INTC': 0.011111188612380408,
 'CSCO': 0.011111295111126287,
 'JPM': 0.011111212354378333,
 'GS': 0.011111213900885054,
 'BAC': 0.011111179143718793,
 'MS': 0.011111171460422687,
 'AXP': 0.011111170532236104,
 'C': 0.011111166775135326,
 'JNJ': 0.0444443229533583,
 'UNH': 0.011111343807737298,
 'PFE': 0.044444235769390834,
 'ABBV': 0.04444425401586451,
 'TSLA': 0.01111119959037893,
 'AMGN': 0.04444407219243035,
 'GILD': 0.04444432447488217,
 'PG': 0.044444278430442845,
 'KO': 0.04444424860370577,
 'NKE': 0.011111324038704228,
 'PEP': 0.04444392106298936,
 'COST': 0.044444242194327,
 'WMT': 0.04444436321847532,
 'TGT': 0.011502437642341646,
 'XOM': 0.011112185823843096,
 'CVX': 0.011111259407763073,
 'NEE': 0.03297992360112413,
 'DUK': 0.0444439534473583,
 'SO': 0.03762800075314799,
 'SLB': 0.011111202014250332,
 'MMM': 0.028995772282074096,
 'CAT': 0.011111308257626953,
 'HON': 0.011111321166848714,
 'GE': 0.011111200584380029,
 'ADP': 0.011111228287854507,
 'AMZN': 0.011114044267634786,
 'META': 0.011111276530642117,
 'HD': 0.011111315549497543,
 'VZ': 0.04444437210764989,
 'MRK': 0.044444327606905115}

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'

# %%
# MVO_GMV_weighted_15 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(MVO_GMV_weighted_15.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(MVO_GMV_weighted_15))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_MVO_GMV_weighted_15 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_MVO_GMV_weighted_15 = pd.DataFrame(weekly_returns_MVO_GMV_weighted_15, columns=['MVO_GMV_weighted_15'])

# %%
# MVO_GMV_weighted_30 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(MVO_GMV_weighted_30.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(MVO_GMV_weighted_30))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_MVO_GMV_weighted_30 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_MVO_GMV_weighted_30 = pd.DataFrame(weekly_returns_MVO_GMV_weighted_30, columns=['MVO_GMV_weighted_30'])

# %%
# MVO_GMV_weighted_45 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(MVO_GMV_weighted_45.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(MVO_GMV_weighted_45))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_MVO_GMV_weighted_45 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_MVO_GMV_weighted_45 = pd.DataFrame(weekly_returns_MVO_GMV_weighted_45, columns=['MVO_GMV_weighted_45'])

# %% [markdown]
# ### Max Return

# %%
MVO_Maxret_weighted_15 = {'AAPL': 0.13333, 'AMZN': 0.03333, 'NVDA': 0.13333, 'JPM': 0.03333, 'PG': 0.13333, 'PFE': 0.03333, 'JNJ': 0.03333, 'KO': 0.03333, 'XOM': 0.03333, 'NEE': 0.03333, 'GOOGL': 0.03333, 'MSFT': 0.13333, 'TSLA': 0.13333, 'NKE': 0.03333, 'BAC': 0.03333}

MVO_Maxret_weighted_30 = {'MSFT': 0.06667, 'AMZN': 0.01667, 'NVDA': 0.06667, 'AAPL': 0.06667, 'GOOGL': 0.06667, 'ADBE': 0.01667, 'JNJ': 0.01667, 'PFE': 0.01667, 'MRK': 0.06667, 'ABT': 0.01667, 'PG': 0.06667, 'KO': 0.01667, 'JPM': 0.01667, 'GS': 0.01667, 'CAT': 0.01667, 'CVX': 0.01667, 'XOM': 0.01667, 'BA': 0.01667, 'TSLA': 0.06667, 'NEE': 0.06667, 'NKE': 0.01667, 'VZ': 0.01667, 'CRM': 0.01667, 'UNH': 0.06667, 'WMT': 0.01667, 'QCOM': 0.06667, 'BAC': 0.01667, 'V': 0.01667, 'MCD': 0.01667, 'INTC': 0.01667}

MVO_Maxret_weighted_45 = {'AAPL': 0.04444, 'GOOGL': 0.01111, 'MSFT': 0.04444, 'NVDA': 0.04444, 'AMD': 0.04444, 'ORCL': 0.04444, 'CRM': 0.01111, 'INTC': 0.01111, 'CSCO': 0.01111, 'JPM': 0.01111, 'GS': 0.01111, 'BAC': 0.01111, 'MS': 0.01111, 'AXP': 0.01111, 'C': 0.01111, 'JNJ': 0.01111, 'UNH': 0.04444, 'PFE': 0.01111, 'ABBV': 0.01111, 'TSLA': 0.04444, 'AMGN': 0.01111, 'GILD': 0.01111, 'PG': 0.04444, 'KO': 0.01111, 'NKE': 0.01111, 'PEP': 0.04444, 'COST': 0.04444, 'WMT': 0.01111, 'TGT': 0.04444, 'XOM': 0.01111, 'CVX': 0.01111, 'NEE': 0.04444, 'DUK': 0.01111, 'SO': 0.01111, 'SLB': 0.01111, 'MMM': 0.01111, 'CAT': 0.01111, 'HON': 0.01111, 'GE': 0.01111, 'ADP': 0.04444, 'AMZN': 0.01111, 'META': 0.01111, 'HD': 0.01111, 'VZ': 0.01111, 'MRK': 0.04444}

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'

# %%
# MVO_Maxret_weighted_15 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(MVO_Maxret_weighted_15.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(MVO_Maxret_weighted_15))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_MVO_Maxret_weighted_15 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_MVO_Maxret_weighted_15 = pd.DataFrame(weekly_returns_MVO_Maxret_weighted_15, columns=['MVO_Maxret_weighted_15'])

# %%
# MVO_Maxret_weighted_30 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(MVO_Maxret_weighted_30.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(MVO_Maxret_weighted_30))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_MVO_Maxret_weighted_30 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_MVO_Maxret_weighted_30 = pd.DataFrame(weekly_returns_MVO_Maxret_weighted_30, columns=['MVO_Maxret_weighted_30'])

# %%
# MVO_Maxret_weighted_45 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(MVO_Maxret_weighted_45.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(MVO_Maxret_weighted_45))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_MVO_Maxret_weighted_45 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_MVO_Maxret_weighted_45 = pd.DataFrame(weekly_returns_MVO_Maxret_weighted_45, columns=['MVO_Maxret_weighted_45'])

# %% [markdown]
# ### Max Sharpe

# %%
MVO_MaxSharpe_weighted_15 = {'AAPL': 0.13333, 'AMZN': 0.03333, 'NVDA': 0.06425, 'JPM': 0.03333, 'PG': 0.13333, 'PFE': 0.03333, 'JNJ': 0.03333, 'KO': 0.03973, 'XOM': 0.03333, 'NEE': 0.09602, 'GOOGL': 0.03333, 'MSFT': 0.13333, 'TSLA': 0.13333, 'NKE': 0.03333, 'BAC': 0.03333}

MVO_MaxSharpe_weighted_30 = {'MSFT': 0.06667, 'AMZN': 0.01667, 'NVDA': 0.06667, 'AAPL': 0.06667, 'GOOGL': 0.01667, 'ADBE': 0.01667, 'JNJ': 0.01667, 'PFE': 0.01667, 'MRK': 0.06667, 'ABT': 0.01667, 'PG': 0.06667, 'KO': 0.01667, 'JPM': 0.01667, 'GS': 0.01667, 'CAT': 0.01667, 'CVX': 0.01667, 'XOM': 0.01667, 'BA': 0.01666, 'TSLA': 0.06667, 'NEE': 0.06667, 'NKE': 0.01667, 'VZ': 0.01667, 'CRM': 0.01667, 'UNH': 0.06667, 'WMT': 0.06667, 'QCOM': 0.01667, 'BAC': 0.01667, 'V': 0.01667, 'MCD': 0.06667, 'INTC': 0.01666}

MVO_MaxSharpe_weighted_45 = {'AAPL': 0.04444, 'GOOGL': 0.01111, 'MSFT': 0.04444, 'NVDA': 0.04444, 'AMD': 0.04444, 'ORCL': 0.01773, 'CRM': 0.01111, 'INTC': 0.01111, 'CSCO': 0.01111, 'JPM': 0.01111, 'GS': 0.01111, 'BAC': 0.01111, 'MS': 0.01111, 'AXP': 0.01111, 'C': 0.01111, 'JNJ': 0.01111, 'UNH': 0.03783, 'PFE': 0.01111, 'ABBV': 0.04444, 'TSLA': 0.04444, 'AMGN': 0.01111, 'GILD': 0.01111, 'PG': 0.04444, 'KO': 0.01111, 'NKE': 0.01111, 'PEP': 0.04444, 'COST': 0.04444, 'WMT': 0.04444, 'TGT': 0.04444, 'XOM': 0.01111, 'CVX': 0.01111, 'NEE': 0.04444, 'DUK': 0.01111, 'SO': 0.04444, 'SLB': 0.01111, 'MMM': 0.01111, 'CAT': 0.01111, 'HON': 0.01111, 'GE': 0.01111, 'ADP': 0.01111, 'AMZN': 0.01111, 'META': 0.01111, 'HD': 0.01111, 'VZ': 0.01111, 'MRK': 0.04444}

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'

# %%
# MVO_MaxSharpe_weighted_15 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(MVO_MaxSharpe_weighted_15.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(MVO_MaxSharpe_weighted_15))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_MVO_MaxSharpe_weighted_15 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_MVO_MaxSharpe_weighted_15 = pd.DataFrame(weekly_returns_MVO_MaxSharpe_weighted_15, columns=['MVO_MaxSharpe_weighted_15'])

# %%
# MVO_MaxSharpe_weighted_30 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(MVO_MaxSharpe_weighted_30.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(MVO_MaxSharpe_weighted_30))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_MVO_MaxSharpe_weighted_30 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_MVO_MaxSharpe_weighted_30 = pd.DataFrame(weekly_returns_MVO_MaxSharpe_weighted_30, columns=['MVO_MaxSharpe_weighted_30'])

# %%
# MVO_MaxSharpe_weighted_45 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(MVO_MaxSharpe_weighted_45.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(MVO_MaxSharpe_weighted_45))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_MVO_MaxSharpe_weighted_45 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_MVO_MaxSharpe_weighted_45 = pd.DataFrame(weekly_returns_MVO_MaxSharpe_weighted_45, columns=['MVO_MaxSharpe_weighted_45'])

# %% [markdown]
# ## **EPO**

# %% [markdown]
# ### GMV

# %%
epo_GMV_weighted_15 = {'AAPL': 0.04575246928786821, 'AMZN': 0.07265377471492239, 'NVDA': 0.06481175209487042, 'JPM': 0.05609762627137712, 'PG': 0.0719435734229653, 'PFE': 0.08771670571734723, 'JNJ': 0.07277777173189208, 'KO': 0.06312539328973277, 'XOM': 0.08609507668538831, 'NEE': 0.07221233969635621, 'GOOGL': 0.05010272070811802, 'MSFT': 0.03828500762569085, 'TSLA': 0.10055629310834088, 'NKE': 0.06129593107749074, 'BAC': 0.05657356456763967}

epo_GMV_weighted_30 = {'MSFT': 0.01666666774419816, 'AMZN': 0.042227409477106695, 'NVDA': 0.03118097512246346, 'AAPL': 0.01666667168358331, 'GOOGL': 0.01809943946174481, 'ADBE': 0.02570202818687248, 'JNJ': 0.035080295142533816, 'PFE': 0.052582684453145526, 'MRK': 0.0475986044981093, 'ABT': 0.022988231711774245, 'PG': 0.03608309079046335, 'KO': 0.027444963001599185, 'JPM': 0.01940313030454212, 'GS': 0.017845787304226788, 'CAT': 0.0336990887241052, 'CVX': 0.03478235727173764, 'XOM': 0.044706637080323186, 'BA': 0.0401698232395637, 'TSLA': 0.06666666228078902, 'NEE': 0.03819709421977127, 'NKE': 0.0283698072324536, 'VZ': 0.05348428364961278, 'CRM': 0.03498396614637049, 'UNH': 0.028482865710042066, 'WMT': 0.05711849959966492, 'QCOM': 0.03681044243477318, 'BAC': 0.020125552595200585, 'V': 0.01666666803231992, 'MCD': 0.02878298920491861, 'INTC': 0.027383283695990274}

epo_GMV_weighted_45 = {'AAPL': 0.011111111751157617, 'GOOGL': 0.01111111297691952, 'MSFT': 0.011111111430617887, 'NVDA': 0.020599077895606076, 'AMD': 0.03653237143698704, 'ORCL': 0.015218203234319534, 'CRM': 0.025585621866165295, 'INTC': 0.0148918676649769, 'CSCO': 0.011111111697909464, 'JPM': 0.011111111820343578, 'GS': 0.011111111721518976, 'BAC': 0.011111111767753831, 'MS': 0.011111111469553583, 'AXP': 0.011111112963466332, 'C': 0.011111112282785603, 'JNJ': 0.01964611725182824, 'UNH': 0.015656892605666366, 'PFE': 0.035078102280757445, 'ABBV': 0.03551029346356419, 'TSLA': 0.044444444168593604, 'AMGN': 0.02325584568021071, 'GILD': 0.04291396596857637, 'PG': 0.0206357790550594, 'KO': 0.013316299685923442, 'NKE': 0.01674069301271715, 'PEP': 0.011111111949044126, 'COST': 0.01826983490242041, 'WMT': 0.04056916285774872, 'TGT': 0.037234796445756904, 'XOM': 0.027932252543989945, 'CVX': 0.01919461191506784, 'NEE': 0.024679849836699883, 'DUK': 0.024462591103417974, 'SO': 0.023809199341675347, 'SLB': 0.04092564530241869, 'MMM': 0.01548505448035055, 'CAT': 0.017262973373497175, 'HON': 0.011111111477449984, 'GE': 0.035796179555666094, 'ADP': 0.011111111372353847, 'AMZN': 0.03089377368024163, 'META': 0.03873632462625635, 'HD': 0.0111111116930388, 'VZ': 0.03677614040679746, 'MRK': 0.03239046798313052}

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'

# %%
# epo_GMV_weighted_15 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(epo_GMV_weighted_15.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(epo_GMV_weighted_15))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_epo_GMV_weighted_15 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_epo_GMV_weighted_15 = pd.DataFrame(weekly_returns_epo_GMV_weighted_15, columns=['epo_GMV_weighted_15'])

# %%
# epo_GMV_weighted_30 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(epo_GMV_weighted_30.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(epo_GMV_weighted_30))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_epo_GMV_weighted_30 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_epo_GMV_weighted_30 = pd.DataFrame(weekly_returns_epo_GMV_weighted_30, columns=['epo_GMV_weighted_30'])

# %%
# epo_GMV_weighted_45 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(epo_GMV_weighted_45.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(epo_GMV_weighted_45))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_epo_GMV_weighted_45 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_epo_GMV_weighted_45 = pd.DataFrame(weekly_returns_epo_GMV_weighted_45, columns=['epo_GMV_weighted_45'])

# %% [markdown]
# ### Max Return

# %%
epo_Maxret_weighted_15 = {'AAPL': 0.13333, 'AMZN': 0.03333, 'NVDA': 0.13333, 'JPM': 0.03333, 'PG': 0.13333, 'PFE': 0.03333, 'JNJ': 0.03333, 'KO': 0.03333, 'XOM': 0.03333, 'NEE': 0.03333, 'GOOGL': 0.03333, 'MSFT': 0.13333, 'TSLA': 0.13333, 'NKE': 0.03333, 'BAC': 0.03333}

epo_Maxret_weighted_30 = {'MSFT': 0.06667, 'AMZN': 0.01667, 'NVDA': 0.06667, 'AAPL': 0.06667, 'GOOGL': 0.06667, 'ADBE': 0.01667, 'JNJ': 0.01667, 'PFE': 0.01667, 'MRK': 0.06667, 'ABT': 0.06667, 'PG': 0.06667, 'KO': 0.01667, 'JPM': 0.01667, 'GS': 0.01667, 'CAT': 0.01667, 'CVX': 0.01667, 'XOM': 0.01667, 'BA': 0.06667, 'TSLA': 0.01667, 'NEE': 0.01667, 'NKE': 0.01667, 'VZ': 0.06667, 'CRM': 0.01667, 'UNH': 0.06667, 'WMT': 0.01667, 'QCOM': 0.01667, 'BAC': 0.01667, 'V': 0.01667, 'MCD': 0.01667, 'INTC': 0.01667}

epo_Maxret_weighted_45 = {'AAPL': 0.04444, 'GOOGL': 0.04444, 'MSFT': 0.04444, 'NVDA': 0.04444, 'AMD': 0.04444, 'ORCL': 0.04444, 'CRM': 0.01111, 'INTC': 0.01111, 'CSCO': 0.01111, 'JPM': 0.01111, 'GS': 0.01111, 'BAC': 0.01111, 'MS': 0.01111, 'AXP': 0.01111, 'C': 0.01111, 'JNJ': 0.04444, 'UNH': 0.01111, 'PFE': 0.01111, 'ABBV': 0.04444, 'TSLA': 0.01111, 'AMGN': 0.01111, 'GILD': 0.04444, 'PG': 0.01111, 'KO': 0.031, 'NKE': 0.029, 'PEP': 0.04444, 'COST': 0.037, 'WMT': 0.04444, 'TGT': 0.016, 'XOM': 0.01111, 'CVX': 0.043, 'NEE': 0.01111, 'DUK': 0.01111, 'SO': 0.01111, 'SLB': 0.01111, 'MMM': 0.01111, 'CAT': 0.01111, 'HON': 0.01111, 'GE': 0.01111, 'ADP': 0.01111, 'AMZN': 0.01111, 'META': 0.01111, 'HD': 0.01111, 'VZ': 0.04444, 'MRK': 0.04444}

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'

# %%
# epo_Maxret_weighted_15 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(epo_Maxret_weighted_15.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(epo_Maxret_weighted_15))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_epo_Maxret_weighted_15 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_epo_Maxret_weighted_15 = pd.DataFrame(weekly_returns_epo_Maxret_weighted_15, columns=['epo_Maxret_weighted_15'])

# %%
# epo_Maxret_weighted_30 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(epo_Maxret_weighted_30.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(epo_Maxret_weighted_30))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_epo_Maxret_weighted_30 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_epo_Maxret_weighted_30 = pd.DataFrame(weekly_returns_epo_Maxret_weighted_30, columns=['epo_Maxret_weighted_30'])

# %%
# epo_Maxret_weighted_45 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(epo_Maxret_weighted_45.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(epo_Maxret_weighted_45))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_epo_Maxret_weighted_45 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_epo_Maxret_weighted_45 = pd.DataFrame(weekly_returns_epo_Maxret_weighted_45, columns=['epo_Maxret_weighted_45'])

# %% [markdown]
# ### Max Sharpe

# %%
epo_MaxSharpe_weighted_15 = {'AAPL': 0.13333, 'AMZN': 0.03333, 'NVDA': 0.13333, 'JPM': 0.03333, 'PG': 0.09539, 'PFE': 0.03333, 'JNJ': 0.03333, 'KO': 0.03333, 'XOM': 0.03707, 'NEE': 0.05699, 'GOOGL': 0.03897, 'MSFT': 0.13333, 'TSLA': 0.13333, 'NKE': 0.03825, 'BAC': 0.03333}

epo_MaxSharpe_weighted_30 = {'MSFT': 0.06667, 'AMZN': 0.01667, 'NVDA': 0.06667, 'AAPL': 0.06667, 'GOOGL': 0.0387, 'ADBE': 0.01667, 'JNJ': 0.01667, 'PFE': 0.01667, 'MRK': 0.06667, 'ABT': 0.02469, 'PG': 0.06667, 'KO': 0.01667, 'JPM': 0.01667, 'GS': 0.01667, 'CAT': 0.01667, 'CVX': 0.01667, 'XOM': 0.01667, 'BA': 0.06667, 'TSLA': 0.0443, 'NEE': 0.02974, 'NKE': 0.01667, 'VZ': 0.01667, 'CRM': 0.05967, 'UNH': 0.04331, 'WMT': 0.06667, 'QCOM': 0.01667, 'BAC': 0.01667, 'V': 0.02625, 'MCD': 0.01667, 'INTC': 0.01667}

epo_MaxSharpe_weighted_45 = {'AAPL': 0.04444, 'GOOGL': 0.04379, 'MSFT': 0.04444, 'NVDA': 0.04444, 'AMD': 0.04444, 'ORCL': 0.04444, 'CRM': 0.01111, 'INTC': 0.01111, 'CSCO': 0.01111, 'JPM': 0.01111, 'GS': 0.01111, 'BAC': 0.01111, 'MS': 0.01111, 'AXP': 0.01111, 'C': 0.01111, 'JNJ': 0.04444, 'UNH': 0.01111, 'PFE': 0.01111, 'ABBV': 0.04444, 'TSLA': 0.01111, 'AMGN': 0.01111, 'GILD': 0.04444, 'PG': 0.01111, 'KO': 0.0312, 'NKE': 0.02923, 'PEP': 0.04444, 'COST': 0.03726, 'WMT': 0.04444, 'TGT': 0.01557, 'XOM': 0.01111, 'CVX': 0.04296, 'NEE': 0.01111, 'DUK': 0.01111, 'SO': 0.01111, 'SLB': 0.01111, 'MMM': 0.01111, 'CAT': 0.01111, 'HON': 0.01111, 'GE': 0.01111, 'ADP': 0.01111, 'AMZN': 0.01111, 'META': 0.01111, 'HD': 0.01111, 'VZ': 0.04444, 'MRK': 0.04444}

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'

# %%
# epo_MaxSharpe_weighted_15 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(epo_MaxSharpe_weighted_15.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(epo_MaxSharpe_weighted_15))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_epo_MaxSharpe_weighted_15 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_epo_MaxSharpe_weighted_15 = pd.DataFrame(weekly_returns_epo_MaxSharpe_weighted_15, columns=['epo_MaxSharpe_weighted_15'])

# %%
# epo_MaxSharpe_weighted_30 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(epo_MaxSharpe_weighted_30.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(epo_MaxSharpe_weighted_30))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_epo_MaxSharpe_weighted_30 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_epo_MaxSharpe_weighted_30 = pd.DataFrame(weekly_returns_epo_MaxSharpe_weighted_30, columns=['epo_MaxSharpe_weighted_30'])

# %%
# epo_MaxSharpe_weighted_45 주간수익률

# 데이터 전처리: 날짜 필터링 및 필요한 종목만 선택
new_market['pricingDate'] = pd.to_datetime(new_market['pricingDate'])
filtered_data = new_market[(new_market['pricingDate'] >= start_date) & (new_market['pricingDate'] <= end_date)]
selected_data = filtered_data[['pricingDate'] + list(epo_MaxSharpe_weighted_45.keys())]

# 'pricingDate' 열을 인덱스로 설정
selected_data.set_index('pricingDate', inplace=True)

# 각 주식의 일일 수익률 계산
daily_returns = selected_data.pct_change().dropna()

# 포트폴리오의 일일 수익률 계산
portfolio_daily_returns = daily_returns.dot(pd.Series(epo_MaxSharpe_weighted_45))

# 주간 수익률 계산 (매주 금요일 기준)
weekly_returns_epo_MaxSharpe_weighted_45 = portfolio_daily_returns.resample('W-FRI').apply(lambda x: (1 + x).prod() - 1)

weekly_returns_epo_MaxSharpe_weighted_45 = pd.DataFrame(weekly_returns_epo_MaxSharpe_weighted_45, columns=['epo_MaxSharpe_weighted_45'])

# %%
#SnP500 주간수익률 계산

from pandas_datareader import data as pdr 
import yfinance as yf 
yf.pdr_override()

def yahoo_reader(ticker, start='2023-05-01', end='2023-10-30', freq=None, calc_return=True, calc_log=False):
    """Read daily data from Yahoo finance
    Assume frea is valid (e.g., 'M', 'W-FRI') 
    calc_return: calculate return (adjusted return) 
    calc_log: calculate log of data
    """
    df = pdr.get_data_yahoo(ticker, start=start, end=end).fillna(method='ffill')['Adj Close']
    
    if freq is not None:
        # Apply resample frequency is necessary
        df = df.resample(freq).last()
    
    if calc_log:
        df = np.log(df)
    if calc_return:
        df = df.pct_change().fillna(0.0)
    
    df = df. dropna()
    df = df[df.index >= start] # in case previous date is included
    
    return df

# %%
# S&P500 주간수익률 (yfinance)

# 날짜 범위 설정
start_date = '2023-05-01'
end_date = '2023-10-30'
freq = 'W-FRI'
dt=52

ticker = ['^GSPC']

SnP500 = yahoo_reader(ticker, start_date, end_date, freq=freq)

SnP500
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2023-05-05    0.000000
# 2023-05-12   -0.002942
# 2023-05-19    0.016464
# 2023-05-26    0.003213
# 2023-06-02    0.018291
# 2023-06-09    0.003851
# 2023-06-16    0.025758
# 2023-06-23   -0.013892
# 2023-06-30    0.023469
# 2023-07-07   -0.011556
# 2023-07-14    0.024203
# 2023-07-21    0.006863
# 2023-07-28    0.010116
# 2023-08-04   -0.022740
# 2023-08-11   -0.003122
# 2023-08-18   -0.021133
# 2023-08-25    0.008239
# 2023-09-01    0.024981
# 2023-09-08   -0.012906
# 2023-09-15   -0.001609
# 2023-09-22   -0.029270
# 2023-09-29   -0.007410
# 2023-10-06    0.004769
# 2023-10-13    0.004475
# 2023-10-20   -0.023943
# 2023-10-27   -0.025281
# Freq: W-FRI, Name: Adj Close, dtype: float64

# %% [markdown]
# # **Performance Evaluation**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %%
weekly_returns_outofsample = pd.concat([weekly_returns_gpt_15, weekly_returns_gpt_30, weekly_returns_gpt_45, weekly_returns_gpt_equal_15, weekly_returns_gpt_equal_30, weekly_returns_gpt_equal_45, weekly_returns_MVO_GMV_weighted_15, weekly_returns_MVO_GMV_weighted_30, weekly_returns_MVO_GMV_weighted_45, weekly_returns_MVO_Maxret_weighted_15, weekly_returns_MVO_Maxret_weighted_30, weekly_returns_MVO_Maxret_weighted_45, weekly_returns_MVO_MaxSharpe_weighted_15, weekly_returns_MVO_MaxSharpe_weighted_30, weekly_returns_MVO_MaxSharpe_weighted_45, weekly_returns_epo_GMV_weighted_15, weekly_returns_epo_GMV_weighted_30, weekly_returns_epo_GMV_weighted_45, weekly_returns_epo_Maxret_weighted_15, weekly_returns_epo_Maxret_weighted_30, weekly_returns_epo_Maxret_weighted_45, weekly_returns_epo_MaxSharpe_weighted_15, weekly_returns_epo_MaxSharpe_weighted_30, weekly_returns_epo_MaxSharpe_weighted_45, SnP500], axis=1)

# %%
# Adj Close 열 이름 수정
weekly_returns_outofsample.rename(columns={'Adj Close': 'SnP500'}, inplace=True)

# %%
weekly_returns_outofsample.to_csv('weekly_returns_outofsample.csv')

# %% [markdown]
# ### performance

# %%
# 성과평가 함수

from scipy.stats import norm
def ret_mean(returns, dt=1): #weekly를 annual로 바꾸고싶으면 dt=52
    return np. mean(returns, axis=0) * dt

def ret_std(returns, dt=1):
    return np.std(returns, ddof=1, axis=0) * np.sqrt(dt)

def total_return(returns):
    return (1 + pd. DataFrame(returns)). prod() - 1

def mdd(returns):
    df_wealth = (pd. DataFrame(returns) + 1). cumprod(axis=0)
    mdd = (df_wealth / df_wealth. expanding(min_periods=0). max()) .min() - 1
    return mdd

def value_at_risk(returns, conf=0.95, assume_norm=False):
    """Value-at-risk either under normality assumption or not 
    Must enter a single column for 'returns'
    """
    if assume_norm:
        # Assume normal distribution of returns
        var = norm. ppf(1 - conf, np. mean(returns), np.std(returns, ddof=1))
    else:
        # No assumption on return distribution
        returns_sorted = returns. sort_values(). reset_index(drop=True)
        i = int(np.floor((1 - conf) * len(returns_sorted)))
        var = returns_sorted[i - 1]
    return var

def conditional_value_at_risk(returns, conf=0.95, assume_norm=False):
    """Conditional value-at-risk either under normality assumption or not
    Must enter a single column for 'returns'
    """
    var = value_at_risk(returns, conf=conf, assume_norm=assume_norm)
    return np. mean(returns[returns <= var])

def cvar(returns, conf=0.95, assume_norm=False):
    """
    Shorthand for conditional_value_at_risk()
    """
    return conditional_value_at_risk(returns, conf=conf, assume_norm=assume_norm)

# %%
# 주간 수익률의 평균
ret_mean(weekly_returns_outofsample)
# Out:
# GPT-weighted_15              0.000880
# GPT-weighted_30              0.001708
# GPT-weighted_45              0.000182
# GPT-equal_15                 0.000406
# GPT-equal_30                 0.000392
# GPT-equal_45                -0.000256
# MVO_GMV_weighted_15         -0.002297
# MVO_GMV_weighted_30         -0.001763
# MVO_GMV_weighted_45         -0.001189
# MVO_Maxret_weighted_15       0.003042
# MVO_Maxret_weighted_30       0.001344
# MVO_Maxret_weighted_45       0.000396
# MVO_MaxSharpe_weighted_15    0.001330
# MVO_MaxSharpe_weighted_30    0.001017
# MVO_MaxSharpe_weighted_45    0.000194
# epo_GMV_weighted_15          0.000326
# epo_GMV_weighted_30          0.000374
# epo_GMV_weighted_45          0.000417
# epo_Maxret_weighted_15       0.003042
# epo_Maxret_weighted_30       0.000830
# epo_Maxret_weighted_45       0.000357
# epo_MaxSharpe_weighted_15    0.002852
# epo_MaxSharpe_weighted_30    0.001272
# epo_MaxSharpe_weighted_45    0.000357
# SnP500                      -0.000043
# ...

# %%
# 연간 수익률 평균
ret_mean(weekly_returns_outofsample, 52)
# Out:
# GPT-weighted_15              0.045758
# GPT-weighted_30              0.088826
# GPT-weighted_45              0.009480
# GPT-equal_15                 0.021134
# GPT-equal_30                 0.020407
# GPT-equal_45                -0.013291
# MVO_GMV_weighted_15         -0.119429
# MVO_GMV_weighted_30         -0.091656
# MVO_GMV_weighted_45         -0.061806
# MVO_Maxret_weighted_15       0.158178
# MVO_Maxret_weighted_30       0.069904
# MVO_Maxret_weighted_45       0.020588
# MVO_MaxSharpe_weighted_15    0.069152
# MVO_MaxSharpe_weighted_30    0.052872
# MVO_MaxSharpe_weighted_45    0.010113
# epo_GMV_weighted_15          0.016965
# epo_GMV_weighted_30          0.019449
# epo_GMV_weighted_45          0.021666
# epo_Maxret_weighted_15       0.158178
# epo_Maxret_weighted_30       0.043161
# epo_Maxret_weighted_45       0.018558
# epo_MaxSharpe_weighted_15    0.148326
# epo_MaxSharpe_weighted_30    0.066157
# epo_MaxSharpe_weighted_45    0.018568
# SnP500                      -0.002224
# ...

# %%
# 주간 수익률의 표준편차
ret_std(weekly_returns_outofsample)
# Out:
# GPT-weighted_15              0.017790
# GPT-weighted_30              0.017579
# GPT-weighted_45              0.015485
# GPT-equal_15                 0.017283
# GPT-equal_30                 0.016878
# GPT-equal_45                 0.015590
# MVO_GMV_weighted_15          0.014844
# MVO_GMV_weighted_30          0.014275
# MVO_GMV_weighted_45          0.014304
# MVO_Maxret_weighted_15       0.022512
# MVO_Maxret_weighted_30       0.017697
# MVO_Maxret_weighted_45       0.015492
# MVO_MaxSharpe_weighted_15    0.019838
# MVO_MaxSharpe_weighted_30    0.015854
# MVO_MaxSharpe_weighted_45    0.015006
# epo_GMV_weighted_15          0.017929
# epo_GMV_weighted_30          0.016810
# epo_GMV_weighted_45          0.015660
# epo_Maxret_weighted_15       0.022512
# epo_Maxret_weighted_30       0.015298
# epo_Maxret_weighted_45       0.015337
# epo_MaxSharpe_weighted_15    0.022744
# epo_MaxSharpe_weighted_30    0.016402
# epo_MaxSharpe_weighted_45    0.015324
# SnP500                       0.016633
# ...

# %%
# 연간 수익률의 표준편차
# weekly_returns_insample.std() * np.sqrt(52)
ret_std(weekly_returns_outofsample, 52)
# Out:
# GPT-weighted_15              0.128282
# GPT-weighted_30              0.126764
# GPT-weighted_45              0.111664
# GPT-equal_15                 0.124629
# GPT-equal_30                 0.121711
# GPT-equal_45                 0.112419
# MVO_GMV_weighted_15          0.107039
# MVO_GMV_weighted_30          0.102937
# MVO_GMV_weighted_45          0.103150
# MVO_Maxret_weighted_15       0.162333
# MVO_Maxret_weighted_30       0.127614
# MVO_Maxret_weighted_45       0.111717
# MVO_MaxSharpe_weighted_15    0.143052
# MVO_MaxSharpe_weighted_30    0.114326
# MVO_MaxSharpe_weighted_45    0.108213
# epo_GMV_weighted_15          0.129286
# epo_GMV_weighted_30          0.121220
# epo_GMV_weighted_45          0.112925
# epo_Maxret_weighted_15       0.162333
# epo_Maxret_weighted_30       0.110313
# epo_Maxret_weighted_45       0.110594
# epo_MaxSharpe_weighted_15    0.164010
# epo_MaxSharpe_weighted_30    0.118278
# epo_MaxSharpe_weighted_45    0.110504
# SnP500                       0.119945
# ...

# %%
# 전체 수익률
total_return(weekly_returns_outofsample)
# Out:
# GPT-weighted_15              0.019816
# GPT-weighted_30              0.042970
# GPT-weighted_45              0.001804
# GPT-equal_15                 0.007102
# GPT-equal_30                 0.006915
# GPT-equal_45                -0.010013
# MVO_GMV_weighted_15         -0.062892
# MVO_GMV_weighted_30         -0.049046
# MVO_GMV_weighted_45         -0.034174
# MVO_Maxret_weighted_15       0.078351
# MVO_Maxret_weighted_30       0.032723
# MVO_Maxret_weighted_45       0.007590
# MVO_MaxSharpe_weighted_15    0.031228
# MVO_MaxSharpe_weighted_30    0.024464
# MVO_MaxSharpe_weighted_45    0.002317
# epo_GMV_weighted_15          0.004621
# epo_GMV_weighted_30          0.006440
# epo_GMV_weighted_45          0.008086
# epo_Maxret_weighted_15       0.078351
# epo_Maxret_weighted_30       0.019547
# epo_Maxret_weighted_45       0.006597
# epo_MaxSharpe_weighted_15    0.072714
# epo_MaxSharpe_weighted_30    0.031312
# epo_MaxSharpe_weighted_45    0.006607
# SnP500                      -0.004564
# ...

# %%
# 주간 Sharpe Ratio
rf = 0.01 # 무위험 수익률을 1%로 가정

(ret_mean(weekly_returns_outofsample) - rf/52) / ret_std(weekly_returns_outofsample)
# Out:
# GPT-weighted_15              0.038655
# GPT-weighted_30              0.086233
# GPT-weighted_45             -0.000646
# GPT-equal_15                 0.012389
# GPT-equal_30                 0.011858
# GPT-equal_45                -0.028730
# MVO_GMV_weighted_15         -0.167682
# MVO_GMV_weighted_30         -0.136950
# MVO_GMV_weighted_45         -0.096535
# MVO_Maxret_weighted_15       0.126583
# MVO_Maxret_weighted_30       0.065096
# MVO_Maxret_weighted_45       0.013143
# MVO_MaxSharpe_weighted_15    0.057342
# MVO_MaxSharpe_weighted_30    0.052003
# MVO_MaxSharpe_weighted_45    0.000145
# epo_GMV_weighted_15          0.007471
# epo_GMV_weighted_30          0.010809
# epo_GMV_weighted_45          0.014326
# epo_Maxret_weighted_15       0.126583
# epo_Maxret_weighted_30       0.041687
# epo_Maxret_weighted_45       0.010731
# epo_MaxSharpe_weighted_15    0.116959
# epo_MaxSharpe_weighted_30    0.065841
# epo_MaxSharpe_weighted_45    0.010752
# SnP500                      -0.014133
# ...

# %%
# 연간 Sharpe Ratio
rf = 0.01 # 무위험 수익률을 1%로 가정

(ret_mean(weekly_returns_outofsample, 52) - rf) / ret_std(weekly_returns_outofsample, 52)
# Out:
# GPT-weighted_15              0.278747
# GPT-weighted_30              0.621834
# GPT-weighted_45             -0.004657
# GPT-equal_15                 0.089336
# GPT-equal_30                 0.085507
# GPT-equal_45                -0.207176
# MVO_GMV_weighted_15         -1.209170
# MVO_GMV_weighted_30         -0.987564
# MVO_GMV_weighted_45         -0.696126
# MVO_Maxret_weighted_15       0.912800
# MVO_Maxret_weighted_30       0.469415
# MVO_Maxret_weighted_45       0.094774
# MVO_MaxSharpe_weighted_15    0.413499
# MVO_MaxSharpe_weighted_30    0.374999
# MVO_MaxSharpe_weighted_45    0.001043
# epo_GMV_weighted_15          0.053876
# epo_GMV_weighted_30          0.077946
# epo_GMV_weighted_45          0.103309
# epo_Maxret_weighted_15       0.912800
# epo_Maxret_weighted_30       0.300606
# epo_Maxret_weighted_45       0.077386
# epo_MaxSharpe_weighted_15    0.843400
# epo_MaxSharpe_weighted_30    0.474786
# epo_MaxSharpe_weighted_45    0.077536
# SnP500                      -0.101916
# ...

# %%
# MDD

mdd(weekly_returns_outofsample)
# Out:
# GPT-weighted_15             -0.114033
# GPT-weighted_30             -0.102669
# GPT-weighted_45             -0.094347
# GPT-equal_15                -0.115157
# GPT-equal_30                -0.099057
# GPT-equal_45                -0.091209
# MVO_GMV_weighted_15         -0.123371
# MVO_GMV_weighted_30         -0.098483
# MVO_GMV_weighted_45         -0.083870
# MVO_Maxret_weighted_15      -0.113214
# MVO_Maxret_weighted_30      -0.099568
# MVO_Maxret_weighted_45      -0.099287
# MVO_MaxSharpe_weighted_15   -0.119323
# MVO_MaxSharpe_weighted_30   -0.093409
# MVO_MaxSharpe_weighted_45   -0.096795
# epo_GMV_weighted_15         -0.119051
# epo_GMV_weighted_30         -0.098434
# epo_GMV_weighted_45         -0.086474
# epo_Maxret_weighted_15      -0.113214
# epo_Maxret_weighted_30      -0.090810
# epo_Maxret_weighted_45      -0.089644
# epo_MaxSharpe_weighted_15   -0.117042
# epo_MaxSharpe_weighted_30   -0.096702
# epo_MaxSharpe_weighted_45   -0.089556
# SnP500                      -0.101448
# ...

# %%
# Performance_Evaluation_outofsample = pd.read_csv('./Performance_Evaluation_outsample_df.csv')
# Performance_Evaluation_outofsample

# %%
import pandas as pd

# Load the data
file_path = './weekly_returns_outofsample.csv'
weekly_returns_data = pd.read_csv(file_path)

# Display the first few rows of the dataframe
weekly_returns_data.head()
# Out:
#    Unnamed: 0  GPT-weighted_15  GPT-weighted_30  GPT-weighted_45  \
# 0  2023-05-05        -0.003398        -0.008656        -0.011103
# 1  2023-05-12         0.003673         0.000145        -0.002240
# 2  2023-05-19         0.018779         0.024100         0.013906
# 3  2023-05-26         0.019255         0.021599         0.007746
# 4  2023-06-02         0.021524         0.021225         0.014646
#
#    GPT-equal_15  GPT-equal_30  GPT-equal_45  MVO_GMV_weighted_15  \
# 0     -0.005766     -0.010712     -0.011976            -0.008743
# 1      0.000130     -0.006822     -0.005485            -0.001415
# 2      0.016713      0.013808      0.009778            -0.000989
# 3      0.015888      0.005679      0.000375            -0.001471
# 4      0.020958      0.023718      0.015856             0.016701
#
#    MVO_GMV_weighted_30  MVO_GMV_weighted_45  ...  epo_GMV_weighted_15  \
# 0            -0.009081            -0.008426  ...            -0.005237
# ...

# %%
import matplotlib.pyplot as plt

# Convert the 'Unnamed: 0' column to datetime and set it as the index
weekly_returns_data['Unnamed: 0'] = pd.to_datetime(weekly_returns_data['Unnamed: 0'])
weekly_returns_data.set_index('Unnamed: 0', inplace=True)

# Calculate the cumulative returns
cumulative_returns = (1 + weekly_returns_data).cumprod()

# %%
# 하이라이트할 포트폴리오 strategies_to_highlight에 넣으면 됨
"""
'GPT-weighted_15','GPT-weighted_30','GPT-weighted_45', 'GPT-equal_15', 'GPT-equal_30', 'GPT-equal_45', 
'MVO_GMV_weighted_15', 'MVO_GMV_weighted_30', 'MVO_GMV_weighted_45', 
'MVO_Maxret_weighted_15', 'MVO_Maxret_weighted_30', 'MVO_Maxret_weighted_45', 
'MVO_MaxSharpe_weighted_15', 'MVO_MaxSharpe_weighted_30', 'MVO_MaxSharpe_weighted_45', 
'epo_GMV_weighted_15', 'epo_GMV_weighted_30', 'epo_GMV_weighted_45', 
'epo_Maxret_weighted_15', 'epo_Maxret_weighted_30', 'epo_Maxret_weighted_45', 
'epo_MaxSharpe_weighted_15', 'epo_MaxSharpe_weighted_30', 'epo_MaxSharpe_weighted_45', 
'SnP500'
"""
strategies_to_highlight = [
                        #    'GPT-weighted_15','GPT-weighted_30','GPT-weighted_45', 'GPT-equal_15', 'GPT-equal_30', 'GPT-equal_45', 
                        #    'MVO_GMV_weighted_15', 'MVO_GMV_weighted_30', 'MVO_GMV_weighted_45', 
                        #    'MVO_Maxret_weighted_15', 'MVO_Maxret_weighted_30', 'MVO_Maxret_weighted_45', 
                        #    'MVO_MaxSharpe_weighted_15', 'MVO_MaxSharpe_weighted_30', 'MVO_MaxSharpe_weighted_45', 
                        #    'epo_GMV_weighted_15', 'epo_GMV_weighted_30', 'epo_GMV_weighted_45', 
                           'epo_Maxret_weighted_15', 'epo_Maxret_weighted_30', 'epo_Maxret_weighted_45', 
                        #    'epo_MaxSharpe_weighted_15', 'epo_MaxSharpe_weighted_30', 'epo_MaxSharpe_weighted_45', 
                           'SnP500']

# Plot the cumulative returns with improved visualization
plt.figure(figsize=(12, 8))

# Plot all strategies with a light and thin line
for column in cumulative_returns.columns:
    if column not in strategies_to_highlight:
        plt.plot(cumulative_returns.index, cumulative_returns[column], label=column, linewidth=0.5, alpha=0.4)

# Highlight selected strategies with a thicker line and no transparency
for strategy in strategies_to_highlight:
    plt.plot(cumulative_returns.index, cumulative_returns[strategy], label=strategy, linewidth=2, alpha=1.0)

# Improve the readability of the plot
plt.title('Cumulative Returns of Portfolios', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Cumulative Returns', fontsize=12)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()

# Show the plot
plt.show()
